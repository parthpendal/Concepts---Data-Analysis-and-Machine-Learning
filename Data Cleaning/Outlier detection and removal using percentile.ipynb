# %%
import pandas as pd

# %%
df=pd.read_excel("C:\\Users\\BHUMIKA\\Desktop\\Data Science\\Assignments\\Dataset_outlier.xlsx")

# %%
df
# Out:
#        name  height
# 0     mohan     5.9
# 1     maria     5.2
# 2     sakib     5.1
# 3       tao     5.5
# 4     virat     4.9
# 5    khusbu     5.4
# 6    dmitry     6.2
# 7    selena     6.5
# 8      john     7.1
# 9     imran    14.5
# 10     jose     6.1
# 11  deepika     5.6
# 12   yoseph     1.2
# 13    binod     5.5

# %%
df.drop("Unnamed: 0",axis=1,inplace=True)

# %%
df
# Out:
#        name  height
# 0     mohan     5.9
# 1     maria     5.2
# 2     sakib     5.1
# 3       tao     5.5
# 4     virat     4.9
# 5    khusbu     5.4
# 6    dmitry     6.2
# 7    selena     6.5
# 8      john     7.1
# 9     imran    14.5
# 10     jose     6.1
# 11  deepika     5.6
# 12   yoseph     1.2
# 13    binod     5.5

# %%
max_threshold=df["height"].quantile(0.95)
max_threshold
# Out:
# 9.689999999999998

# %%
min_threshold=df["height"].quantile(0.05)
min_threshold
# Out:
# 3.6050000000000004

# %%
df[(df["height"]>min_threshold) &  (df["height"]<max_threshold)]
# Out:
#        name  height
# 0     mohan     5.9
# 1     maria     5.2
# 2     sakib     5.1
# 3       tao     5.5
# 4     virat     4.9
# 5    khusbu     5.4
# 6    dmitry     6.2
# 7    selena     6.5
# 8      john     7.1
# 10     jose     6.1
# 11  deepika     5.6
# 13    binod     5.5

# %%
#Now lets explore banglore property prices dataset

# %%
df=pd.read_csv("C:\\Users\\BHUMIKA\\Desktop\\Data Science\\Assignments\\Banglore_Property_Outlier.csv")
df.head(50)
# Out:
#                     location       size  total_sqft  bath   price  bhk  \
# 0   Electronic City Phase II      2 BHK     1056.00   2.0   39.07    2
# 1           Chikka Tirupathi  4 Bedroom     2600.00   5.0  120.00    4
# 2                Uttarahalli      3 BHK     1440.00   2.0   62.00    3
# 3         Lingadheeranahalli      3 BHK     1521.00   3.0   95.00    3
# 4                   Kothanur      2 BHK     1200.00   2.0   51.00    2
# 5                 Whitefield      2 BHK     1170.00   2.0   38.00    2
# 6           Old Airport Road      4 BHK     2732.00   4.0  204.00    4
# 7               Rajaji Nagar      4 BHK     3300.00   4.0  600.00    4
# 8               Marathahalli      3 BHK     1310.00   3.0   63.25    3
# 9                      other  6 Bedroom     1020.00   6.0  370.00    6
# 10                Whitefield      3 BHK     1800.00   2.0   70.00    3
# 11                Whitefield  4 Bedroom     2785.00   5.0  295.00    4
# ...

# %%
Q1=df['price_per_sqft'].quantile(0.25)
Q3=df['price_per_sqft'].quantile(0.75)
IQR=Q3-Q1

# %%
IQR
# Out:
# 3050.0

# %%
Q1
# Out:
# 4267.0

# %%
Q3
# Out:
# 7317.0

# %%
Q1-(1.5*IQR)
# Out:
# -308.0

# %%
(Q3+(1.5*IQR))
# Out:
# 11892.0

# %%
df1= df[(df['price_per_sqft'] > (Q1-(1.5*IQR))) & (df['price_per_sqft'] <(Q3+(1.5*IQR)))]

# %%
df1.head(50)
# Out:
#                     location       size  total_sqft  bath   price  bhk  \
# 0   Electronic City Phase II      2 BHK     1056.00   2.0   39.07    2
# 1           Chikka Tirupathi  4 Bedroom     2600.00   5.0  120.00    4
# 2                Uttarahalli      3 BHK     1440.00   2.0   62.00    3
# 3         Lingadheeranahalli      3 BHK     1521.00   3.0   95.00    3
# 4                   Kothanur      2 BHK     1200.00   2.0   51.00    2
# 5                 Whitefield      2 BHK     1170.00   2.0   38.00    2
# 6           Old Airport Road      4 BHK     2732.00   4.0  204.00    4
# 8               Marathahalli      3 BHK     1310.00   3.0   63.25    3
# 10                Whitefield      3 BHK     1800.00   2.0   70.00    3
# 11                Whitefield  4 Bedroom     2785.00   5.0  295.00    4
# 12        7th Phase JP Nagar      2 BHK     1000.00   2.0   38.00    2
# 13                 Gottigere      2 BHK     1100.00   2.0   40.00    2
# ...

# %%
df1.shape
# Out:
# (11935, 7)
