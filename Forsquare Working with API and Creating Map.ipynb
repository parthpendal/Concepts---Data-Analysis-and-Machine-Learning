# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation


# !pip install geopy
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize


! pip install folium==0.5.0
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
c:\users\bhumika\anaconda3\python.exe -m pip install --upgrade pip
# Out:
#   File "<ipython-input-111-2407f241befc>", line 23
#     c:\users\bhumika\anaconda3\python.exe -m pip install --upgrade pip
#                                                                       ^
# SyntaxError: unexpected character after line continuation character

# %%
CLIENT_ID = 'CRQM3BUXWSMS04TN1WZLK5ZGXNWADYAHE0UWR1N5FBQH0LTA' # your Foursquare ID
CLIENT_SECRET = 'RXMRFZRJICEUCYJTB3CMHOJOWYIXOET0JJTEPUH4I5OVV3KA' # your Foursquare Secret
ACCESS_TOKEN = '' # your FourSquare Access Token
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: CRQM3BUXWSMS04TN1WZLK5ZGXNWADYAHE0UWR1N5FBQH0LTA
# CLIENT_SECRET:RXMRFZRJICEUCYJTB3CMHOJOWYIXOET0JJTEPUH4I5OVV3KA

# %%
address = '2 Robinson Rd, Rocky Hill, CT - 06067'
geolocator=Nominatim(user_agent="foursquare_agent")
location= geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print([latitude, longitude])
longlag= str(latitude) + "," + str(longitude)
Bank_map=folium.Map([latitude, longitude],zoom_start=13)
Bank_map
# Out:
# [41.634922, -72.686832]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import json
url = 'https://api.foursquare.com/v2/venues/explore'
params = dict(
client_id=CLIENT_ID,
client_secret=CLIENT_SECRET,
v='20180323',
ll=longlag,
query="bank",
limit=5
)
resp = requests.get(url=url, params=params).json()
resp
Banks=resp['response']['groups'][0]['items']
dataframe = json_normalize(Banks)
dataframe.head()
# Out:
# C:\Users\BHUMIKA\anaconda3\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                        referralId  reasons.count  \
# 0  e-0-4e7734192271ffa4e7b23987-0              0
# 1  e-0-4bad41f8f964a520e33e3be3-1              0
# 2  e-0-4c77f20920bb199c294f0529-2              0
# 3  e-0-4dee50ea18385379de5909da-3              0
# 4  e-0-4d1dfcb06e8c3704fffee19f-4              0
#
#                                        reasons.items  \
# 0  [{'summary': 'This spot is popular', 'type': '...
# 1  [{'summary': 'This spot is popular', 'type': '...
# 2  [{'summary': 'This spot is popular', 'type': '...
# 3  [{'summary': 'This spot is popular', 'type': '...
# 4  [{'summary': 'This spot is popular', 'type': '...
#
#                    venue.id       venue.name     venue.location.address  \
# 0  4e7734192271ffa4e7b23987    Citizens Bank           856 Cromwell Ave
# ...

# %%
for x in range(0,5):
    print(float(dataframe.loc[x,["venue.location.lat"]]),float(dataframe.loc[x,["venue.location.lng"]]),str(dataframe.loc[x,["venue.name"]]))
    folium.CircleMarker([float(dataframe.loc[x,["venue.location.lat"]]),float(dataframe.loc[x,["venue.location.lng"]])], 
                        radius=15, color='green',
                        fill_color="Red",fill = True,
                       popup=str(dataframe.loc[x,["venue.name"]])
                       ).add_to(Bank_map)
Bank_map
# Out:
# 41.646845 -72.6775549 venue.name    Citizens Bank
# Name: 0, dtype: object
# 41.644240103591336 -72.67792778086469 venue.name    Bank of America
# Name: 1, dtype: object
# 41.65372961946342 -72.67903983592987 venue.name    TD Bank
# Name: 2, dtype: object
# 41.65812193477437 -72.67495196719864 venue.name    Wells Fargo
# Name: 3, dtype: object
# 41.60677596499517 -72.67767660319805 venue.name    Citizens Bank
# Name: 4, dtype: object
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
